# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv('ml-latest-small/movies.csv')
ratings = pd.read_csv('ml-latest-small/ratings.csv')
tags = pd.read_csv('ml-latest-small/tags.csv')
print('movies: ', movies.shape)
print('ratings: ', ratings.shape)
print('tags: ', tags.shape)
# Out:
# movies:  (9742, 3)
# ratings:  (100836, 4)
# tags:  (3683, 4)

# %%
movies.head(5)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings.head(5)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
tags.head(5)
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
df = pd.merge(ratings, movies, on='movieId' , how='left')
df = df.drop('title', axis=1)
df.head(5)
# Out:
#    userId  movieId  rating  timestamp  \
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %%
df['genres'] = df['genres'].str.split('|')

# %%
df.head(5)
# Out:
#    userId  movieId  rating  timestamp  \
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
#
#                                               genres
# 0  [Adventure, Animation, Children, Comedy, Fantasy]
# 1                                  [Comedy, Romance]
# 2                          [Action, Crime, Thriller]
# 3                                [Mystery, Thriller]
# 4                         [Crime, Mystery, Thriller]

# %%
tags['tag'] = tags['tag'].str.split('|')
tags.drop('timestamp', axis=1, inplace=True)

# %%
tags = tags.groupby(['userId','movieId'])['tag'].apply(lambda x: ','.join(x.astype(str))).reset_index()
tags.head(5)
# Out:
#    userId  movieId                                                tag
# 0       2    60756     ['funny'],['Highly quotable'],['will ferrell']
# 1       2    89774             ['Boxing story'],['MMA'],['Tom Hardy']
# 2       2   106782  ['drugs'],['Leonardo DiCaprio'],['Martin Scors...
# 3       7    48516                                   ['way too long']
# 4      18      431               ['Al Pacino'],['gangster'],['mafia']

# %%
df = pd.merge(df, tags, on=['userId','movieId'], how='left')

# %%
df.shape
# Out:
# (100836, 6)

# %%
df['tag'] = df['tag'].apply(lambda d: d if isinstance(d, list) else [])
df['genres'] = df['genres'].apply(lambda d: d if isinstance(d, list) else [])

# %%
df
# Out:
#         userId  movieId  rating   timestamp  \
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# 5            1       70     3.0   964982400
# 6            1      101     5.0   964980868
# 7            1      110     4.0   964982176
# 8            1      151     5.0   964984041
# 9            1      157     5.0   964984100
# 10           1      163     5.0   964983650
# 11           1      216     5.0   964981208
# 12           1      223     3.0   964980985
# 13           1      231     5.0   964981179
# 14           1      235     4.0   964980908
# 15           1      260     5.0   964981680
# 16           1      296     3.0   964982967
# 17           1      316     3.0   964982310
# 18           1      333     5.0   964981179
# 19           1      349     4.0   964982563
# 20           1      356     4.0   964980962
# 21           1      362     5.0   964982588
# 22           1      367     4.0   964981710
# 23           1      423     3.0   964982363
# 24           1      441     4.0   964980868
# 25           1      457     5.0   964981909
# 26           1      480     4.0   964982346
# 27           1      500     3.0   964981208
# 28           1      527     5.0   964984002
# 29           1      543     4.0   964981179
# ...        ...      ...     ...         ...
# 100806     610   150401     3.0  1479543210
# 100807     610   152077     4.0  1493845817
# 100808     610   152081     4.0  1493846503
# 100809     610   152372     3.5  1493848841
# 100810     610   155064     3.5  1493848456
# 100811     610   156371     5.0  1479542831
# 100812     610   156726     4.5  1493848444
# 100813     610   157296     4.0  1493846563
# 100814     610   158238     5.0  1479545219
# 100815     610   158721     3.5  1479542491
# 100816     610   158872     3.5  1493848024
# 100817     610   158956     3.0  1493848947
# 100818     610   159093     3.0  1493847704
# 100819     610   160080     3.0  1493848031
# 100820     610   160341     2.5  1479545749
# 100821     610   160527     4.5  1479544998
# 100822     610   160571     3.0  1493848537
# 100823     610   160836     3.0  1493844794
# 100824     610   161582     4.0  1493847759
# 100825     610   161634     4.0  1493848362
# 100826     610   162350     3.5  1493849971
# 100827     610   163937     3.5  1493848789
# 100828     610   163981     3.5  1493850155
# 100829     610   164179     5.0  1493845631
# 100830     610   166528     4.0  1493879365
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
#                                                    genres tag
# 0       [Adventure, Animation, Children, Comedy, Fantasy]  []
# 1                                       [Comedy, Romance]  []
# 2                               [Action, Crime, Thriller]  []
# 3                                     [Mystery, Thriller]  []
# 4                              [Crime, Mystery, Thriller]  []
# 5                      [Action, Comedy, Horror, Thriller]  []
# 6                     [Adventure, Comedy, Crime, Romance]  []
# 7                                    [Action, Drama, War]  []
# 8                           [Action, Drama, Romance, War]  []
# 9                                           [Comedy, War]  []
# 10                             [Action, Romance, Western]  []
# 11                                               [Comedy]  []
# 12                                               [Comedy]  []
# 13                                    [Adventure, Comedy]  []
# 14                                        [Comedy, Drama]  []
# 15                            [Action, Adventure, Sci-Fi]  []
# 16                       [Comedy, Crime, Drama, Thriller]  []
# 17                            [Action, Adventure, Sci-Fi]  []
# 18                                               [Comedy]  []
# 19                       [Action, Crime, Drama, Thriller]  []
# 20                          [Comedy, Drama, Romance, War]  []
# 21                         [Adventure, Children, Romance]  []
# 22                       [Action, Comedy, Crime, Fantasy]  []
# 23                                     [Action, Thriller]  []
# 24                                               [Comedy]  []
# 25                                             [Thriller]  []
# 26                  [Action, Adventure, Sci-Fi, Thriller]  []
# 27                                        [Comedy, Drama]  []
# 28                                           [Drama, War]  []
# 29                            [Comedy, Romance, Thriller]  []
# ...                                                   ...  ..
# 100806                                    [Action, Crime]  []
# 100807                                         [Thriller]  []
# 100808   [Action, Adventure, Animation, Children, Comedy]  []
# 100809                                           [Horror]  []
# 100810                           [Drama, Horror, Mystery]  []
# 100811                                           [Comedy]  []
# 100812                                         [Thriller]  []
# 100813                     [Adventure, Animation, Comedy]  []
# 100814                         [Crime, Mystery, Thriller]  []
# 100815                         [Action, Comedy, Thriller]  []
# 100816                                [Animation, Comedy]  []
# 100817                           [Action, Horror, Sci-Fi]  []
# 100818                         [Action, Comedy, Thriller]  []
# 100819                   [Action, Comedy, Horror, Sci-Fi]  []
# 100820                                 [Action, Thriller]  []
# 100821                             [Action, Crime, Drama]  []
# 100822                                           [Horror]  []
# 100823                          [Action, Drama, Thriller]  []
# 100824                                     [Crime, Drama]  []
# 100825                                         [Thriller]  []
# 100826                                  [Action, Western]  []
# 100827                                 [Horror, Thriller]  []
# 100828                                           [Horror]  []
# 100829                                           [Sci-Fi]  []
# 100830               [Action, Adventure, Fantasy, Sci-Fi]  []
# 100831                          [Drama, Horror, Thriller]  []
# 100832                          [Action, Crime, Thriller]  []
# 100833                                           [Horror]  []
# 100834                                   [Action, Sci-Fi]  []
# 100835                   [Action, Crime, Drama, Thriller]  []
#
# [100836 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
train_data, test_data = train_test_split(df, test_size=0.2, stratify=df.userId)

# %%
train_data = train_data.sort_values(['userId', 'movieId'])
train_data
# Out:
#         userId  movieId  rating   timestamp  \
# 0            1        1     4.0   964982703
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# 6            1      101     5.0   964980868
# 8            1      151     5.0   964984041
# 9            1      157     5.0   964984100
# 10           1      163     5.0   964983650
# 11           1      216     5.0   964981208
# 12           1      223     3.0   964980985
# 13           1      231     5.0   964981179
# 14           1      235     4.0   964980908
# 15           1      260     5.0   964981680
# 17           1      316     3.0   964982310
# 18           1      333     5.0   964981179
# 19           1      349     4.0   964982563
# 20           1      356     4.0   964980962
# 21           1      362     5.0   964982588
# 22           1      367     4.0   964981710
# 23           1      423     3.0   964982363
# 26           1      480     4.0   964982346
# 27           1      500     3.0   964981208
# 28           1      527     5.0   964984002
# 29           1      543     4.0   964981179
# 30           1      552     4.0   964982653
# 33           1      592     4.0   964982271
# 34           1      593     4.0   964983793
# 35           1      596     5.0   964982838
# 37           1      648     3.0   964982563
# 38           1      661     5.0   964982838
# ...        ...      ...     ...         ...
# 100798     610   146309     4.0  1493850187
# 100799     610   147657     4.0  1479544210
# 100800     610   147662     3.0  1479544214
# 100802     610   148424     3.0  1493850521
# 100803     610   148626     4.0  1493847175
# 100804     610   149011     3.5  1493848843
# 100805     610   149406     3.5  1479542295
# 100806     610   150401     3.0  1479543210
# 100807     610   152077     4.0  1493845817
# 100809     610   152372     3.5  1493848841
# 100810     610   155064     3.5  1493848456
# 100811     610   156371     5.0  1479542831
# 100813     610   157296     4.0  1493846563
# 100814     610   158238     5.0  1479545219
# 100816     610   158872     3.5  1493848024
# 100817     610   158956     3.0  1493848947
# 100818     610   159093     3.0  1493847704
# 100819     610   160080     3.0  1493848031
# 100820     610   160341     2.5  1479545749
# 100823     610   160836     3.0  1493844794
# 100824     610   161582     4.0  1493847759
# 100826     610   162350     3.5  1493849971
# 100827     610   163937     3.5  1493848789
# 100828     610   163981     3.5  1493850155
# 100829     610   164179     5.0  1493845631
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
#                                                    genres tag
# 0       [Adventure, Animation, Children, Comedy, Fantasy]  []
# 2                               [Action, Crime, Thriller]  []
# 3                                     [Mystery, Thriller]  []
# 4                              [Crime, Mystery, Thriller]  []
# 6                     [Adventure, Comedy, Crime, Romance]  []
# 8                           [Action, Drama, Romance, War]  []
# 9                                           [Comedy, War]  []
# 10                             [Action, Romance, Western]  []
# 11                                               [Comedy]  []
# 12                                               [Comedy]  []
# 13                                    [Adventure, Comedy]  []
# 14                                        [Comedy, Drama]  []
# 15                            [Action, Adventure, Sci-Fi]  []
# 17                            [Action, Adventure, Sci-Fi]  []
# 18                                               [Comedy]  []
# 19                       [Action, Crime, Drama, Thriller]  []
# 20                          [Comedy, Drama, Romance, War]  []
# 21                         [Adventure, Children, Romance]  []
# 22                       [Action, Comedy, Crime, Fantasy]  []
# 23                                     [Action, Thriller]  []
# 26                  [Action, Adventure, Sci-Fi, Thriller]  []
# 27                                        [Comedy, Drama]  []
# 28                                           [Drama, War]  []
# 29                            [Comedy, Romance, Thriller]  []
# 30                   [Action, Adventure, Comedy, Romance]  []
# 33                              [Action, Crime, Thriller]  []
# 34                              [Crime, Horror, Thriller]  []
# 35                [Animation, Children, Fantasy, Musical]  []
# 37                 [Action, Adventure, Mystery, Thriller]  []
# 38      [Adventure, Animation, Children, Fantasy, Musi...  []
# ...                                                   ...  ..
# 100798                     [Action, Adventure, Animation]  []
# 100799                                           [Action]  []
# 100800                                [Action, Adventure]  []
# 100802                                    [Comedy, Drama]  []
# 100803                                            [Drama]  []
# 100804                            [Comedy, Drama, Horror]  []
# 100805                     [Action, Adventure, Animation]  []
# 100806                                    [Action, Crime]  []
# 100807                                         [Thriller]  []
# 100809                                           [Horror]  []
# 100810                           [Drama, Horror, Mystery]  []
# 100811                                           [Comedy]  []
# 100813                     [Adventure, Animation, Comedy]  []
# 100814                         [Crime, Mystery, Thriller]  []
# 100816                                [Animation, Comedy]  []
# 100817                           [Action, Horror, Sci-Fi]  []
# 100818                         [Action, Comedy, Thriller]  []
# 100819                   [Action, Comedy, Horror, Sci-Fi]  []
# 100820                                 [Action, Thriller]  []
# 100823                          [Action, Drama, Thriller]  []
# 100824                                     [Crime, Drama]  []
# 100826                                  [Action, Western]  []
# 100827                                 [Horror, Thriller]  []
# 100828                                           [Horror]  []
# 100829                                           [Sci-Fi]  []
# 100831                          [Drama, Horror, Thriller]  []
# 100832                          [Action, Crime, Thriller]  []
# 100833                                           [Horror]  []
# 100834                                   [Action, Sci-Fi]  []
# 100835                   [Action, Crime, Drama, Thriller]  []
#
# [80668 rows x 6 columns]

# %%
test_data = test_data.sort_values(['userId','movieId'])
test_data
# Out:
#         userId  movieId  rating   timestamp  \
# 1            1        3     4.0   964981247
# 5            1       70     3.0   964982400
# 7            1      110     4.0   964982176
# 16           1      296     3.0   964982967
# 24           1      441     4.0   964980868
# 25           1      457     5.0   964981909
# 31           1      553     5.0   964984153
# 32           1      590     4.0   964982546
# 36           1      608     5.0   964982931
# 39           1      673     3.0   964981775
# 43           1      804     4.0   964980499
# 45           1      923     5.0   964981529
# 52           1     1025     5.0   964982791
# 57           1     1042     4.0   964981179
# 62           1     1089     5.0   964982951
# 65           1     1097     5.0   964981680
# 74           1     1213     5.0   964982951
# 84           1     1265     4.0   964983599
# 86           1     1275     5.0   964982290
# 88           1     1282     5.0   964982703
# 91           1     1348     4.0   964983393
# 101          1     1580     3.0   964981125
# 103          1     1617     5.0   964982951
# 110          1     1793     4.0   964981404
# 113          1     1920     4.0   964981780
# 115          1     1954     5.0   964982176
# 124          1     2048     5.0   964982791
# 128          1     2090     5.0   964982838
# 131          1     2096     4.0   964982838
# 145          1     2273     4.0   964982310
# ...        ...      ...     ...         ...
# 100694     610   112183     5.0  1493845270
# 100697     610   112556     4.0  1493845119
# 100705     610   113345     2.5  1479543342
# 100707     610   113565     4.0  1493848798
# 100722     610   115727     5.0  1479544153
# 100724     610   116799     4.5  1493849263
# 100726     610   116977     3.0  1479544278
# 100732     610   119145     4.5  1493846044
# 100735     610   120799     2.5  1493845842
# 100736     610   121231     5.0  1493848188
# 100738     610   122884     3.0  1493848465
# 100741     610   122900     3.5  1493846126
# 100742     610   122904     3.0  1493845981
# 100743     610   122920     5.0  1493845626
# 100750     610   129937     3.0  1493849305
# 100753     610   130634     4.5  1493846403
# 100762     610   134393     3.5  1479542759
# 100763     610   134853     3.5  1493845106
# 100773     610   136602     4.0  1493848627
# 100776     610   138036     3.5  1493846318
# 100793     610   142598     4.0  1493848878
# 100797     610   145951     0.5  1493849019
# 100801     610   148166     3.5  1479542224
# 100808     610   152081     4.0  1493846503
# 100812     610   156726     4.5  1493848444
# 100815     610   158721     3.5  1479542491
# 100821     610   160527     4.5  1479544998
# 100822     610   160571     3.0  1493848537
# 100825     610   161634     4.0  1493848362
# 100830     610   166528     4.0  1493879365
#
#                                                    genres tag
# 1                                       [Comedy, Romance]  []
# 5                      [Action, Comedy, Horror, Thriller]  []
# 7                                    [Action, Drama, War]  []
# 16                       [Comedy, Crime, Drama, Thriller]  []
# 24                                               [Comedy]  []
# 25                                             [Thriller]  []
# 31                               [Action, Drama, Western]  []
# 32                            [Adventure, Drama, Western]  []
# 36                       [Comedy, Crime, Drama, Thriller]  []
# 39      [Adventure, Animation, Children, Comedy, Fanta...  []
# 43                                      [Comedy, Romance]  []
# 45                                       [Drama, Mystery]  []
# 52                [Animation, Children, Fantasy, Musical]  []
# 57                                        [Comedy, Drama]  []
# 62                             [Crime, Mystery, Thriller]  []
# 65                              [Children, Drama, Sci-Fi]  []
# 74                                         [Crime, Drama]  []
# 84                             [Comedy, Fantasy, Romance]  []
# 86                           [Action, Adventure, Fantasy]  []
# 88                [Animation, Children, Fantasy, Musical]  []
# 91                                               [Horror]  []
# 101                              [Action, Comedy, Sci-Fi]  []
# 103                 [Crime, Film-Noir, Mystery, Thriller]  []
# 110                                              [Comedy]  []
# 113                   [Animation, Children, Fantasy, War]  []
# 115                                               [Drama]  []
# 124                  [Action, Animation, Children, Crime]  []
# 128        [Adventure, Animation, Children, Crime, Drama]  []
# 131                        [Animation, Children, Musical]  []
# 145                     [Action, Comedy, Crime, Thriller]  []
# ...                                                   ...  ..
# 100694                                    [Comedy, Drama]  []
# 100697                                  [Drama, Thriller]  []
# 100705                        [Action, Adventure, Sci-Fi]  []
# 100707                                 [Horror, Thriller]  []
# 100722                                [Action, Adventure]  []
# 100724           [Comedy, Crime, Drama, Mystery, Romance]  []
# 100726                                           [Comedy]  []
# 100732                 [Action, Adventure, Comedy, Crime]  []
# 100735              [Action, Adventure, Sci-Fi, Thriller]  []
# 100736                                           [Horror]  []
# 100738                        [Fantasy, Horror, Thriller]  []
# 100741                        [Action, Adventure, Sci-Fi]  []
# 100742                [Action, Adventure, Comedy, Sci-Fi]  []
# 100743                         [Action, Sci-Fi, Thriller]  []
# 100750                   [Action, Crime, Drama, Thriller]  []
# 100753                          [Action, Crime, Thriller]  []
# 100762                                  [Comedy, Romance]  []
# 100763  [Adventure, Animation, Children, Comedy, Drama...  []
# 100773                                 [Horror, Thriller]  []
# 100776                        [Action, Adventure, Comedy]  []
# 100793                                           [Horror]  []
# 100797                                 [Action, Thriller]  []
# 100801                                      [Documentary]  []
# 100808   [Action, Adventure, Animation, Children, Comedy]  []
# 100812                                         [Thriller]  []
# 100815                         [Action, Comedy, Thriller]  []
# 100821                             [Action, Crime, Drama]  []
# 100822                                           [Horror]  []
# 100825                                         [Thriller]  []
# 100830               [Action, Adventure, Fantasy, Sci-Fi]  []
#
# [20168 rows x 6 columns]

# %%
train_data.to_csv('training_data.csv')
test_data.to_csv('testing_data.csv')
